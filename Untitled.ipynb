# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\admin\Downloads\motor_data11-14lats.csv')

# %%
print(df.head())
# Out:
#    SEX INSR_BEGIN   INSR_END EFFECTIVE_YR  INSR_TYPE  INSURED_VALUE   PREMIUM  \
# 0    0  08-AUG-13  07-AUG-14           08       1202      519755.22  7209.140
# 1    0  08-AUG-12  07-AUG-13           08       1202      519755.22  7203.890
# 2    0  08-AUG-11  07-AUG-12           08       1202      519755.22  7045.804
# 3    0  08-JUL-11  07-AUG-11           08       1202      519755.22   287.250
# 4    0  08-AUG-13  07-AUG-14           08       1202      285451.24  4286.900
#
#     OBJECT_ID  PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY TYPE_VEHICLE  CCM_TON  \
# 0  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 1  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 2  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 3  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 4  5000029901     2010.0        4.0                7.0      Pick-up   2494.0
#
#      MAKE      USAGE  CLAIM_PAID
# ...

# %%
print(df.tail())
# Out:
#         SEX INSR_BEGIN   INSR_END EFFECTIVE_YR  INSR_TYPE  INSURED_VALUE  \
# 293532    2  11-AUG-12  10-AUG-13           88       1201            0.0
# 293533    2  11-AUG-11  10-AUG-12           88       1201            0.0
# 293534    2  01-JUN-13  31-MAY-14           13       1201       250000.0
# 293535    0  08-JUL-12  07-JUL-13           85       1202            0.0
# 293536    0  08-JUL-11  07-JUL-12           85       1202            0.0
#
#          PREMIUM   OBJECT_ID  PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY  \
# 293532   577.700  5000047311     1985.0        4.0                NaN
# 293533   695.318  5000047311     1985.0        4.0                NaN
# 293534  4778.450  5000949222     1993.0        4.0                NaN
# 293535  1057.427  5000049231     2017.0        2.0                0.0
# 293536  1001.537  5000049231     2017.0        2.0                0.0
#
#        TYPE_VEHICLE  CCM_TON    MAKE            USAGE  CLAIM_PAID
# ...

# %%
print(df.head(3))
# Out:
#    SEX INSR_BEGIN   INSR_END EFFECTIVE_YR  INSR_TYPE  INSURED_VALUE   PREMIUM  \
# 0    0  08-AUG-13  07-AUG-14           08       1202      519755.22  7209.140
# 1    0  08-AUG-12  07-AUG-13           08       1202      519755.22  7203.890
# 2    0  08-AUG-11  07-AUG-12           08       1202      519755.22  7045.804
#
#     OBJECT_ID  PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY TYPE_VEHICLE  CCM_TON  \
# 0  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 1  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 2  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
#
#      MAKE      USAGE  CLAIM_PAID
# 0  NISSAN  Own Goods         NaN
# 1  NISSAN  Own Goods         NaN
# 2  NISSAN  Own Goods         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293537 entries, 0 to 293536
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SEX                293537 non-null  int64
#  1   INSR_BEGIN         293537 non-null  object
#  2   INSR_END           293537 non-null  object
#  3   EFFECTIVE_YR       293536 non-null  object
#  4   INSR_TYPE          293537 non-null  int64
#  5   INSURED_VALUE      293537 non-null  float64
#  6   PREMIUM            293529 non-null  float64
#  7   OBJECT_ID          293537 non-null  int64
#  8   PROD_YEAR          293431 non-null  float64
#  9   SEATS_NUM          293397 non-null  float64
#  10  CARRYING_CAPACITY  212172 non-null  float64
#  11  TYPE_VEHICLE       293537 non-null  object
#  12  CCM_TON            293535 non-null  float64
#  13  MAKE               293537 non-null  object
#  14  USAGE              293537 non-null  object
# ...

# %%
df.describe()
# Out:
#                  SEX      INSR_TYPE  INSURED_VALUE        PREMIUM  \
# count  293537.000000  293537.000000   2.935370e+05  293529.000000
# mean        0.510154    1201.714268   4.146088e+05    6476.056811
# std         0.645379       0.455481   8.353941e+05    9039.792585
# min         0.000000    1201.000000   0.000000e+00       0.000000
# 25%         0.000000    1201.000000   0.000000e+00     804.850000
# 50%         0.000000    1202.000000   2.000000e+05    3154.017000
# 75%         1.000000    1202.000000   5.854500e+05    8293.213000
# max         2.000000    1204.000000   2.500000e+08  227278.880000
#
#           OBJECT_ID      PROD_YEAR      SEATS_NUM  CARRYING_CAPACITY  \
# count  2.935370e+05  293431.000000  293397.000000      212172.000000
# mean   5.000237e+09    2001.394900       6.182504         648.037967
# std    1.683947e+05      10.305091      13.045420        4838.746032
# min    5.000018e+09    1950.000000       0.000000           0.000000
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# SEX                       0
# INSR_BEGIN                0
# INSR_END                  0
# EFFECTIVE_YR              1
# INSR_TYPE                 0
# INSURED_VALUE             0
# PREMIUM                   8
# OBJECT_ID                 0
# PROD_YEAR               106
# SEATS_NUM               140
# CARRYING_CAPACITY     81365
# TYPE_VEHICLE              0
# CCM_TON                   2
# MAKE                      0
# USAGE                     0
# CLAIM_PAID           271164
# dtype: int64

# %%
# Finding and counting duplicate rows
duplicates = df.duplicated().sum()
print("Number of duplicate entries:", duplicates)
# Out:
# Number of duplicate entries: 120

# %%
import matplotlib.pyplot as plt

# Plot a histogram for the 'Temperature' column to check for anomalies
df['PREMIUM'].hist()
plt.show()

# %%
print(df.columns)
# Out:
# Index(['SEX', 'INSR_BEGIN', 'INSR_END', 'EFFECTIVE_YR', 'INSR_TYPE',
#        'INSURED_VALUE', 'PREMIUM', 'OBJECT_ID', 'PROD_YEAR', 'SEATS_NUM',
#        'CARRYING_CAPACITY', 'TYPE_VEHICLE', 'CCM_TON', 'MAKE', 'USAGE',
#        'CLAIM_PAID'],
#       dtype='object')

# %%
df.dtypes
# Out:
# SEX                    int64
# INSR_BEGIN            object
# INSR_END              object
# EFFECTIVE_YR          object
# INSR_TYPE              int64
# INSURED_VALUE        float64
# PREMIUM              float64
# OBJECT_ID              int64
# PROD_YEAR            float64
# SEATS_NUM            float64
# CARRYING_CAPACITY    float64
# TYPE_VEHICLE          object
# CCM_TON              float64
# MAKE                  object
# USAGE                 object
# CLAIM_PAID           float64
# dtype: object

# %%
df.size
# Out:
# 4696592

# %%
df.shape
# Out:
# (293537, 16)

# %%
import matplotlib.pyplot as plt

# Data
motor_data = ["INSURED_VALUE", "PREMIUM", "INSR_TYPE", "EFFECTIVE", "OBJECT_ID"]
numbers = [1, 2, 3, 4, 5]  # Adjusted numbers to match the length of motor_data

# Plot
plt.figure(figsize=(10, 5))
plt.plot(motor_data, numbers, marker='o', linestyle='-', color='red')
plt.title('Motor Insecure CSV')
plt.xlabel('Motor Data')
plt.ylabel('Numbers')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
hours_studied = [1, 2, 3, 4, 5, 6, 7, 8, 9]
test_scores = [55, 60, 65, 65, 70, 70, 75, 76, 80]

# Plot
plt.scatter(hours_studied, test_scores)
plt.title('Scatter Plot of Hours Studied vs. Test Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Test Scores')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data: random daily temperatures for one year
data = np.random.normal(loc=20.0, scale=5.0, size=365)  # average temp 20, std deviation 5

# Plot
plt.hist(data, bins=20, color='blue', alpha=0.7)
plt.title('Histogram of Daily Temperatures Over One Year')
plt.xlabel('Temperature (degrees Celsius)')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
salespersons = ['Alice', 'Bob', 'Charlie', 'Diana']
sales = [260, 300, 220, 320]

# Creating bar chart
plt.figure(figsize=(8, 5))
plt.bar(salespersons, sales, color='blue', alpha=0.7)
plt.title('Sales Transactions by Salesperson')
plt.xlabel('Salesperson')
plt.ylabel('Number of Transactions')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
brands = ['Apple', 'Samsung', 'Huawei', 'Xiaomi']
market_share = [30, 30, 20, 20]

# Creating pie chart
plt.figure(figsize=(7, 7))
plt.pie(market_share, labels=brands, autopct='%1.1f%%', startangle=140)
plt.title('Smartphone Market Share')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test scores data simulating a skewed distribution
test_scores = np.random.normal(70, 10, 100)
test_scores = np.append(test_scores, [40, 40, 90, 100, 100, 100])  # Adding outliers and some very high scores

# Creating box plot
plt.figure(figsize=(6, 8))
plt.boxplot(test_scores, vert=True, patch_artist=True, meanline=True, showmeans=True)
plt.title('Distribution of Test Scores')
plt.ylabel('Test Scores')
plt.grid(True)
plt.show()
